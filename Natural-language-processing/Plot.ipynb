# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(5):
    data = np.load(f"recordings/Up{i}.npy")[:12000]
    plt.plot(data)
plt.title("Up")
# Out:
# Text(0.5, 1.0, 'Up')

# %%
for i in range(5):
    data = np.load(f"recordings/Down{i}.npy")[:12000]
    plt.plot(data)
plt.title("Down")
# Out:
# Text(0.5, 1.0, 'Down')

# %%
for i in range(5):
    data = np.load(f"recordings/Left{i}.npy")[:16000]
    plt.plot(data)
plt.title("Left")
# Out:
# Text(0.5, 1.0, 'Left')

# %%
for i in range(5):
    data = np.load(f"recordings/Right{i}.npy")[:15000]
    plt.plot(data)
plt.title("Right")
# Out:
# Text(0.5, 1.0, 'Right')
